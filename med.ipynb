# %%
import matplotlib.pyplot as plt
import pydicom

# %%
filename = "/Users/profemzy/DjangoProjects/medtools/dcms/1.2.392.200036.9116.2.5.1.48.1221172481.1520063264.777696.dcm"
dataset = pydicom.dcmread(filename)

# %%
pat_name = dataset.PatientName
display_name = pat_name.family_name + ", " + pat_name.given_name
print("Patient's name...:", display_name)
print("Patient id.......:", dataset.PatientID)
print("Modality.........:", dataset.Modality)
print("Study Date.......:", dataset.StudyDate)
# Out:
# Patient's name...: OLADOJA MARIAM,
# Patient id.......: 1353473
# Modality.........: CT
# Study Date.......: 20180303

# %%
if 'PixelData' in dataset:
    rows = int(dataset.Rows)
    cols = int(dataset.Columns)
    print("Image size.......: {rows:d} x {cols:d}, {size:d} bytes".format(
        rows=rows, cols=cols, size=len(dataset.PixelData)))
    if 'PixelSpacing' in dataset:
        print("Pixel spacing....:", dataset.PixelSpacing)

# use .get() if not sure the item exists, and want a default value if missing
print("Slice location...:", dataset.get('SliceLocation', "(missing)"))
# Out:
# Image size.......: 512 x 512, 524288 bytes
# Pixel spacing....: ['0.500', '0.500']
# Slice location...: +125.00

# %%
# plot the image using matplotlib
plt.imshow(dataset.pixel_array, cmap=plt.cm.bone)
plt.show()
